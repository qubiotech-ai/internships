# %% [markdown]
# # Generación de D112: Trial 2 de generación de sCMB siguiendo el pipeline de momeni en el dataset de CSIRO

# %% [markdown]
# Versión mejorada de generación de sCMBs sobre dataset CSIRO sujetos sanos

# %%
import os
import glob
import numpy as np
import nibabel as nib
import json
from scipy.ndimage import binary_erosion, generate_binary_structure, rotate
from skimage.transform import downscale_local_mean
import time
import shutil
from nilearn.image import resample_to_img

# %%
# ==========================================
# 1. CONFIGURACIÓN MASIVA (nnU-Net v2)
# ==========================================
# Ruta origen (AIBL limpio)
INPUT_ROOT_DIR = "/media/PORT-DISK/Practicas/MicroBleeds_Generation/CSIRO_dataset/NoCMBSubject/data"

# Ruta destino: IMPORTANTE usar formato DatasetXXX_Nombre
DATASET_NAME = "Dataset112_SyntheticCMB"
NNUNET_RAW_DIR = "/media/PORT-DISK/Practicas/MicroBleeds_Generation/CSIRO/nnUNet_raw" 
OUTPUT_DIR = os.path.join(NNUNET_RAW_DIR, DATASET_NAME)

# Parámetros
RANDOM_SEED = 42

# --- NUEVA LÓGICA DE DISTRIBUCIÓN (Trial 2) ---
TOTAL_SUBJECTS = 313
# 20% Limpios (63), 50% con 12 sCMB (156), 30% con 20 sCMB (94)
densities = [0]*63 + [12]*156 + [20]*94
np.random.seed(RANDOM_SEED)
np.random.shuffle(densities) 

# Crear estructura de carpetas nnU-Net v2
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(os.path.join(OUTPUT_DIR, "imagesTr"), exist_ok=True)
    os.makedirs(os.path.join(OUTPUT_DIR, "labelsTr"), exist_ok=True)

# %%
# ==========================================
# 2. MOTOR MATEMÁTICO (Momeni Validado)
# ==========================================
def generate_momeni_gaussian(target_volume_mm3, voxel_size_mm, oversample=10):
    K = 1.175 
    term = (3 * target_volume_mm3) / (4 * np.pi * (K**3))
    sigma_t_mm = np.cbrt(term)
    
    # --- MEJORA 4: MAYOR ANISOTROPÍA ---
    # Aumentamos el rango de variación de los ejes para que no siempre sean casi-esferas
    rmin, rmax = 0.4, 1.2 # Antes 0.5, 0.9
    sigma_x_mm = sigma_t_mm * np.random.uniform(rmin, rmax)
    sigma_y_mm = sigma_t_mm * np.random.uniform(rmin, rmax)
    # sigma_z se calcula para mantener el volumen constante, lo cual es correcto
    sigma_z_mm = (sigma_t_mm**3) / (sigma_x_mm * sigma_y_mm)

    hr_vx_size = np.array(voxel_size_mm) / oversample
    sx_px = sigma_x_mm / hr_vx_size[0]
    sy_px = sigma_y_mm / hr_vx_size[1]
    sz_px = sigma_z_mm / hr_vx_size[2]
    
    max_sigma = max(sx_px, sy_px, sz_px)
    grid_size = int(max_sigma * 4) + 1 # Antes era 6, con 4 es suficiente tras el sharpening y thresholding
    if grid_size % 2 == 0: grid_size += 1
    
    cx, cy, cz = grid_size // 2, grid_size // 2, grid_size // 2
    
    x = np.arange(grid_size) - cx
    y = np.arange(grid_size) - cy
    z = np.arange(grid_size) - cz
    xx, yy, zz = np.meshgrid(x, y, z, indexing='ij')
    
    exponent = - ( (xx**2)/(2*sx_px**2) + (yy**2)/(2*sy_px**2) + (zz**2)/(2*sz_px**2) )
    gaussian = np.exp(exponent)

    # EL CAMBIO PARA EL TRIAL 2 (Momeni-Pure):
    # Half-thresholding: lo que sea menor al 50% del pico (0.5), se va a 0 (así eliminamos la cola de la gaussiana)
    gaussian[gaussian < 0.5] = 0
    # Luego aplicamos sharpening elevando al cuadrado para que sea caída más brusca
    gaussian = gaussian**2
    
    angle_x = np.random.uniform(-30, 30)
    angle_y = np.random.uniform(-30, 30)
    angle_z = np.random.uniform(-30, 30)
    
    img_rot = rotate(gaussian, angle_x, axes=(0,1), reshape=False, order=1)
    img_rot = rotate(img_rot, angle_y, axes=(1,2), reshape=False, order=1)
    img_rot = rotate(img_rot, angle_z, axes=(0,2), reshape=False, order=1)
    
    low_res_blob = downscale_local_mean(img_rot, (oversample, oversample, oversample))
    if low_res_blob.max() > 0:
        low_res_blob /= low_res_blob.max()
        
    return low_res_blob



def implant_and_label(image_data, label_data, center, volume_mm3, voxel_dims, strength):
    x, y, z = center
    lesion_pattern = generate_momeni_gaussian(volume_mm3, voxel_dims, oversample=10)
    
    p_shape = lesion_pattern.shape
    dx, dy, dz = p_shape[0]//2, p_shape[1]//2, p_shape[2]//2
    x_s, x_e = x - dx, x - dx + p_shape[0]
    y_s, y_e = y - dy, y - dy + p_shape[1]
    z_s, z_e = z - dz, z - dz + p_shape[2]
    
    if x_s < 0 or x_e > image_data.shape[0] or \
       y_s < 0 or y_e > image_data.shape[1] or \
       z_s < 0 or z_e > image_data.shape[2]:
        return image_data, label_data
    
    roi_img = image_data[x_s:x_e, y_s:y_e, z_s:z_e]
    if roi_img.shape != lesion_pattern.shape:
        lesion_pattern = lesion_pattern[:roi_img.shape[0], :roi_img.shape[1], :roi_img.shape[2]]
    
    
    # --- MEJORA 2: AJUSTE DE ATENUACIÓN (STRENGTH) ---
    # Usamos el 'strength' calculado fuera para que cubra el rango de las FNs (0.4 - 0.9)
    mask_multiplier = 1 - (lesion_pattern * strength)

    # [NUEVO] Forzamos que el núcleo de la lesión sea un poco más sólido
    # Esto evita ratios de 0.95 que son básicamente aire
    mask_multiplier = np.clip(mask_multiplier, 0.02, 1.0)

    image_data[x_s:x_e, y_s:y_e, z_s:z_e] = roi_img * mask_multiplier
    
    # La máscara de ground truth (Label) debe ser un poco más estricta 
    # que la caída de señal para que la red no aprenda bordes difusos como lesión
    roi_label = label_data[x_s:x_e, y_s:y_e, z_s:z_e]
    lesion_mask_binary = (lesion_pattern >= 0.5).astype(int)
    label_data[x_s:x_e, y_s:y_e, z_s:z_e] = np.maximum(roi_label, lesion_mask_binary)
    
    return image_data, label_data

def get_segmentation_sampling_mask(image_path, img_shape):
    """
    Localiza la segmentación de SynthSeg y genera un mapa de probabilidad
    basado en pesos anatómicos validados (55% Cortex, 35% WM, 10% Deep GM).
    Incluir resampling  espacial dado que SynthSeg resamplea a vóxeles 1x1x1mm.
    """
    # 1. Localización corregida del archivo de segmentación
    # image_path: .../NoCMBSubject/data/archivo.nii.gz
    data_dir = os.path.dirname(image_path)          # .../NoCMBSubject/data
    root_dir = os.path.dirname(data_dir)          # .../NoCMBSubject
    
    filename = os.path.basename(image_path)
    seg_name = filename.replace('.nii.gz', '_segmentation.nii.gz')
    seg_path = os.path.join(root_dir, "segmentations", seg_name)

    if not os.path.exists(seg_path):
        raise FileNotFoundError(f"No se encuentra la segmentación en: {seg_path}")

    # 2. Carga de objetos NIfTI
    img_nii = nib.load(image_path)
    seg_nii = nib.load(seg_path)

    # 3. RESAMPLING ESPACIAL EXACTO
    # 'interpolation=nearest' asegura que las etiquetas no se degraden
    seg_resampled_nii = resample_to_img(seg_nii, img_nii, interpolation='nearest')
    seg_data = seg_resampled_nii.get_fdata().astype(int)

    # Ahora seg_data.shape es EXACTAMENTE img_shape (176, 256, 80)
    # y la anatomía coincide milímetro a milímetro.

    # 3. Definición de etiquetas SynthSeg
    labels_wm = [2, 41]
    labels_dgm = [10, 49, 11, 50, 12, 51, 13, 52, 17, 53, 18, 54]
    labels_cortex = list(range(1000, 3000))

    # 4. Creación del mapa de pesos
    # Inicializamos con ceros (probabilidad 0 para CSF, hueso y fondo)
    weight_map = np.zeros(img_shape, dtype=float)

    # Asignación de pesos objetivos (distribución relativa)
    target_weights = {
        'cortex': 0.55,
        'wm': 0.35,
        'dgm': 0.10
    }

    # Calculamos las máscaras booleanas para cada grupo
    mask_cortex = np.isin(seg_data, labels_cortex)
    mask_wm = np.isin(seg_data, labels_wm)
    mask_dgm = np.isin(seg_data, labels_dgm)

    # Para que la probabilidad total de una región sea el target_weight, 
    # cada vóxel individual debe tener (peso_objetivo / número_de_vóxeles)
    for mask, weight in zip([mask_cortex, mask_wm, mask_dgm], target_weights.values()):
        n_voxels = np.sum(mask)
        if n_voxels > 0:
            weight_map[mask] = weight / n_voxels

    # 5. Obtener coordenadas y sus probabilidades
    valid_indices = np.argwhere(weight_map > 0)
    # Extraemos las probabilidades de esos índices específicos
    probs = weight_map[weight_map > 0]
    
    # Normalización final por seguridad (debe sumar 1)
    probs /= probs.sum()

    return valid_indices, probs

# %% [markdown]
# ### Ejecutamos y dividimos en dataset train y test con muestreo estratificado

# %%
# ==========================================
# 3. PREPARACIÓN ESTRATIFICADA Y EJECUCIÓN
# ==========================================
print(f"Iniciando Pipeline Trial 2 (Momeni-Pure)...")
nifti_files = sorted(glob.glob(os.path.join(INPUT_ROOT_DIR, "**/*.nii.gz"), recursive=True))

# Configuración de estratos (Total 313)
# Grupo: [Cantidad Total, Cantidad Test]
estratos = {
    0:  [63, 7],   # Sanos
    12: [156, 16], # Moderados
    20: [94, 10]   # Severos
}

# Crear listas de densidad para Train y Test
train_pool = [0]*56 + [12]*140 + [20]*84
test_pool  = [0]*7  + [12]*16  + [20]*10

np.random.seed(RANDOM_SEED)
np.random.shuffle(train_pool)
np.random.shuffle(test_pool)

# Unimos: los primeros 280 son Train, los últimos 33 son Test
final_densities = train_pool + test_pool
final_splits = ["Tr"] * 280 + ["Ts"] * 33

# Crear carpetas necesarias
for folder in ["imagesTr", "labelsTr", "imagesTs", "labelsTs"]:
    os.makedirs(os.path.join(OUTPUT_DIR, folder), exist_ok=True)

# --- BUCLE DE GENERACIÓN ---
for idx, file_path in enumerate(nifti_files):
    num_lesions = final_densities[idx]
    split = final_splits[idx]
    subject_id = f"CSIRO_{idx+1:03d}"
    
    print(f"[{idx+1}/313] {subject_id} | Objetivo: {num_lesions} sCMB | Destino: {split}")
    
    try:
        nii = nib.load(file_path)
        data_img = nii.get_fdata().astype(float)
        data_label = np.zeros(data_img.shape, dtype=np.uint8)
        voxel_dims = nii.header.get_zooms()

        if num_lesions > 0:
            valid_coords, probs = get_segmentation_sampling_mask(file_path, data_img.shape)
            if valid_coords is not None:
                random_indices = np.random.choice(len(valid_coords), size=num_lesions, replace=False, p=probs)
                for coord in valid_coords[random_indices]:
                    vol_rnd = np.random.triangular(0.8, 2.5, 15.0)
                    str_rnd = np.random.triangular(0.70, 0.80, 0.98)
                    data_img, data_label = implant_and_label(data_img, data_label, coord, vol_rnd, voxel_dims, str_rnd)

        # Guardado Directo
        img_ext = "_0000.nii.gz"
        nib.save(nib.Nifti1Image(data_img, nii.affine, nii.header), 
                 os.path.join(OUTPUT_DIR, f"images{split}", f"{subject_id}{img_ext}"))
        nib.save(nib.Nifti1Image(data_label, nii.affine, nii.header), 
                 os.path.join(OUTPUT_DIR, f"labels{split}", f"{subject_id}.nii.gz"))
        
    except Exception as e:
        print(f"    ERROR en {subject_id}: {e}")

# ==========================================
# 4. DATASET.JSON AUTOMÁTICO
# ==========================================
json_dict = {
    "channel_names": {"0": "SWI"},
    "labels": {"background": 0, "CMB": 1},
    "numTraining": 280,
    "file_ending": ".nii.gz",
    "name": DATASET_NAME,
    "reference": "Momeni-Pure Method (Stratified Trial 2)",
    "description": "20% Healthy, 50% 12 sCMB, 30% 20 sCMB. Integrated anatomical weights.",
    "overwrite_image_reader_writer": "SimpleITKIO"
}

with open(os.path.join(OUTPUT_DIR, "dataset.json"), 'w') as f:
    json.dump(json_dict, f, indent=4)

print(f"\nDATASET LISTO: {len(train_pool)} Entrenamiento / {len(test_pool)} Test")
# Out:
# Iniciando Pipeline Trial 2 (Momeni-Pure)...
# [1/313] CSIRO_001 | Objetivo: 0 sCMB | Destino: Tr
# [2/313] CSIRO_002 | Objetivo: 12 sCMB | Destino: Tr
# [3/313] CSIRO_003 | Objetivo: 20 sCMB | Destino: Tr
# [4/313] CSIRO_004 | Objetivo: 20 sCMB | Destino: Tr
# [5/313] CSIRO_005 | Objetivo: 12 sCMB | Destino: Tr
# [6/313] CSIRO_006 | Objetivo: 0 sCMB | Destino: Tr
# [7/313] CSIRO_007 | Objetivo: 12 sCMB | Destino: Tr
# [8/313] CSIRO_008 | Objetivo: 20 sCMB | Destino: Tr
# [9/313] CSIRO_009 | Objetivo: 12 sCMB | Destino: Tr
# [10/313] CSIRO_010 | Objetivo: 12 sCMB | Destino: Tr
# [11/313] CSIRO_011 | Objetivo: 20 sCMB | Destino: Tr
# [12/313] CSIRO_012 | Objetivo: 12 sCMB | Destino: Tr
# [13/313] CSIRO_013 | Objetivo: 20 sCMB | Destino: Tr
# [14/313] CSIRO_014 | Objetivo: 20 sCMB | Destino: Tr
# [15/313] CSIRO_015 | Objetivo: 0 sCMB | Destino: Tr
# [16/313] CSIRO_016 | Objetivo: 20 sCMB | Destino: Tr
# [17/313] CSIRO_017 | Objetivo: 12 sCMB | Destino: Tr
# [18/313] CSIRO_018 | Objetivo: 12 sCMB | Destino: Tr
# [19/313] CSIRO_019 | Objetivo: 12 sCMB | Destino: Tr
# [20/313] CSIRO_020 | Objetivo: 12 sCMB | Destino: Tr
# [21/313] CSIRO_021 | Objetivo: 20 sCMB | Destino: Tr
# [22/313] CSIRO_022 | Objetivo: 20 sCMB | Destino: Tr
# [23/313] CSIRO_023 | Objetivo: 20 sCMB | Destino: Tr
# [24/313] CSIRO_024 | Objetivo: 20 sCMB | Destino: Tr
# [25/313] CSIRO_025 | Objetivo: 0 sCMB | Destino: Tr
# [26/313] CSIRO_026 | Objetivo: 12 sCMB | Destino: Tr
# [27/313] CSIRO_027 | Objetivo: 12 sCMB | Destino: Tr
# [28/313] CSIRO_028 | Objetivo: 12 sCMB | Destino: Tr
# [29/313] CSIRO_029 | Objetivo: 20 sCMB | Destino: Tr
# [30/313] CSIRO_030 | Objetivo: 20 sCMB | Destino: Tr
# [31/313] CSIRO_031 | Objetivo: 0 sCMB | Destino: Tr
# [32/313] CSIRO_032 | Objetivo: 12 sCMB | Destino: Tr
# [33/313] CSIRO_033 | Objetivo: 12 sCMB | Destino: Tr
# [34/313] CSIRO_034 | Objetivo: 20 sCMB | Destino: Tr
# [35/313] CSIRO_035 | Objetivo: 12 sCMB | Destino: Tr
# [36/313] CSIRO_036 | Objetivo: 0 sCMB | Destino: Tr
# [37/313] CSIRO_037 | Objetivo: 0 sCMB | Destino: Tr
# [38/313] CSIRO_038 | Objetivo: 0 sCMB | Destino: Tr
# [39/313] CSIRO_039 | Objetivo: 12 sCMB | Destino: Tr
# [40/313] CSIRO_040 | Objetivo: 12 sCMB | Destino: Tr
# [41/313] CSIRO_041 | Objetivo: 12 sCMB | Destino: Tr
# [42/313] CSIRO_042 | Objetivo: 20 sCMB | Destino: Tr
# [43/313] CSIRO_043 | Objetivo: 20 sCMB | Destino: Tr
# [44/313] CSIRO_044 | Objetivo: 12 sCMB | Destino: Tr
# [45/313] CSIRO_045 | Objetivo: 20 sCMB | Destino: Tr
# [46/313] CSIRO_046 | Objetivo: 20 sCMB | Destino: Tr
# [47/313] CSIRO_047 | Objetivo: 12 sCMB | Destino: Tr
# [48/313] CSIRO_048 | Objetivo: 0 sCMB | Destino: Tr
# [49/313] CSIRO_049 | Objetivo: 20 sCMB | Destino: Tr
# [50/313] CSIRO_050 | Objetivo: 12 sCMB | Destino: Tr
# [51/313] CSIRO_051 | Objetivo: 12 sCMB | Destino: Tr
# [52/313] CSIRO_052 | Objetivo: 12 sCMB | Destino: Tr
# [53/313] CSIRO_053 | Objetivo: 0 sCMB | Destino: Tr
# [54/313] CSIRO_054 | Objetivo: 12 sCMB | Destino: Tr
# [55/313] CSIRO_055 | Objetivo: 12 sCMB | Destino: Tr
# [56/313] CSIRO_056 | Objetivo: 0 sCMB | Destino: Tr
# [57/313] CSIRO_057 | Objetivo: 12 sCMB | Destino: Tr
# [58/313] CSIRO_058 | Objetivo: 12 sCMB | Destino: Tr
# [59/313] CSIRO_059 | Objetivo: 12 sCMB | Destino: Tr
# [60/313] CSIRO_060 | Objetivo: 0 sCMB | Destino: Tr
# [61/313] CSIRO_061 | Objetivo: 12 sCMB | Destino: Tr
# [62/313] CSIRO_062 | Objetivo: 20 sCMB | Destino: Tr
# [63/313] CSIRO_063 | Objetivo: 12 sCMB | Destino: Tr
# [64/313] CSIRO_064 | Objetivo: 12 sCMB | Destino: Tr
# [65/313] CSIRO_065 | Objetivo: 0 sCMB | Destino: Tr
# [66/313] CSIRO_066 | Objetivo: 0 sCMB | Destino: Tr
# [67/313] CSIRO_067 | Objetivo: 12 sCMB | Destino: Tr
# [68/313] CSIRO_068 | Objetivo: 0 sCMB | Destino: Tr
# [69/313] CSIRO_069 | Objetivo: 0 sCMB | Destino: Tr
# [70/313] CSIRO_070 | Objetivo: 20 sCMB | Destino: Tr
# [71/313] CSIRO_071 | Objetivo: 20 sCMB | Destino: Tr
# [72/313] CSIRO_072 | Objetivo: 12 sCMB | Destino: Tr
# [73/313] CSIRO_073 | Objetivo: 20 sCMB | Destino: Tr
# [74/313] CSIRO_074 | Objetivo: 12 sCMB | Destino: Tr
# [75/313] CSIRO_075 | Objetivo: 12 sCMB | Destino: Tr
# [76/313] CSIRO_076 | Objetivo: 20 sCMB | Destino: Tr
# [77/313] CSIRO_077 | Objetivo: 12 sCMB | Destino: Tr
# [78/313] CSIRO_078 | Objetivo: 12 sCMB | Destino: Tr
# [79/313] CSIRO_079 | Objetivo: 0 sCMB | Destino: Tr
# [80/313] CSIRO_080 | Objetivo: 12 sCMB | Destino: Tr
# [81/313] CSIRO_081 | Objetivo: 20 sCMB | Destino: Tr
# [82/313] CSIRO_082 | Objetivo: 12 sCMB | Destino: Tr
# [83/313] CSIRO_083 | Objetivo: 20 sCMB | Destino: Tr
# [84/313] CSIRO_084 | Objetivo: 12 sCMB | Destino: Tr
# [85/313] CSIRO_085 | Objetivo: 12 sCMB | Destino: Tr
# [86/313] CSIRO_086 | Objetivo: 0 sCMB | Destino: Tr
# [87/313] CSIRO_087 | Objetivo: 12 sCMB | Destino: Tr
# [88/313] CSIRO_088 | Objetivo: 20 sCMB | Destino: Tr
# [89/313] CSIRO_089 | Objetivo: 0 sCMB | Destino: Tr
# [90/313] CSIRO_090 | Objetivo: 12 sCMB | Destino: Tr
# [91/313] CSIRO_091 | Objetivo: 12 sCMB | Destino: Tr
# [92/313] CSIRO_092 | Objetivo: 12 sCMB | Destino: Tr
# [93/313] CSIRO_093 | Objetivo: 20 sCMB | Destino: Tr
# [94/313] CSIRO_094 | Objetivo: 12 sCMB | Destino: Tr
# [95/313] CSIRO_095 | Objetivo: 12 sCMB | Destino: Tr
# [96/313] CSIRO_096 | Objetivo: 0 sCMB | Destino: Tr
# [97/313] CSIRO_097 | Objetivo: 20 sCMB | Destino: Tr
# [98/313] CSIRO_098 | Objetivo: 12 sCMB | Destino: Tr
# [99/313] CSIRO_099 | Objetivo: 12 sCMB | Destino: Tr
# [100/313] CSIRO_100 | Objetivo: 12 sCMB | Destino: Tr
# [101/313] CSIRO_101 | Objetivo: 20 sCMB | Destino: Tr
# [102/313] CSIRO_102 | Objetivo: 12 sCMB | Destino: Tr
# [103/313] CSIRO_103 | Objetivo: 12 sCMB | Destino: Tr
# [104/313] CSIRO_104 | Objetivo: 12 sCMB | Destino: Tr
# [105/313] CSIRO_105 | Objetivo: 12 sCMB | Destino: Tr
# [106/313] CSIRO_106 | Objetivo: 12 sCMB | Destino: Tr
# [107/313] CSIRO_107 | Objetivo: 12 sCMB | Destino: Tr
# [108/313] CSIRO_108 | Objetivo: 12 sCMB | Destino: Tr
# [109/313] CSIRO_109 | Objetivo: 12 sCMB | Destino: Tr
# [110/313] CSIRO_110 | Objetivo: 0 sCMB | Destino: Tr
# [111/313] CSIRO_111 | Objetivo: 12 sCMB | Destino: Tr
# [112/313] CSIRO_112 | Objetivo: 12 sCMB | Destino: Tr
# [113/313] CSIRO_113 | Objetivo: 12 sCMB | Destino: Tr
# [114/313] CSIRO_114 | Objetivo: 12 sCMB | Destino: Tr
# [115/313] CSIRO_115 | Objetivo: 12 sCMB | Destino: Tr
# [116/313] CSIRO_116 | Objetivo: 12 sCMB | Destino: Tr
# [117/313] CSIRO_117 | Objetivo: 12 sCMB | Destino: Tr
# [118/313] CSIRO_118 | Objetivo: 20 sCMB | Destino: Tr
# [119/313] CSIRO_119 | Objetivo: 12 sCMB | Destino: Tr
# [120/313] CSIRO_120 | Objetivo: 20 sCMB | Destino: Tr
# [121/313] CSIRO_121 | Objetivo: 12 sCMB | Destino: Tr
# [122/313] CSIRO_122 | Objetivo: 12 sCMB | Destino: Tr
# [123/313] CSIRO_123 | Objetivo: 20 sCMB | Destino: Tr
# [124/313] CSIRO_124 | Objetivo: 0 sCMB | Destino: Tr
# [125/313] CSIRO_125 | Objetivo: 20 sCMB | Destino: Tr
# [126/313] CSIRO_126 | Objetivo: 20 sCMB | Destino: Tr
# [127/313] CSIRO_127 | Objetivo: 20 sCMB | Destino: Tr
# [128/313] CSIRO_128 | Objetivo: 12 sCMB | Destino: Tr
# [129/313] CSIRO_129 | Objetivo: 12 sCMB | Destino: Tr
# [130/313] CSIRO_130 | Objetivo: 12 sCMB | Destino: Tr
# [131/313] CSIRO_131 | Objetivo: 12 sCMB | Destino: Tr
# [132/313] CSIRO_132 | Objetivo: 12 sCMB | Destino: Tr
# [133/313] CSIRO_133 | Objetivo: 12 sCMB | Destino: Tr
# [134/313] CSIRO_134 | Objetivo: 12 sCMB | Destino: Tr
# [135/313] CSIRO_135 | Objetivo: 12 sCMB | Destino: Tr
# [136/313] CSIRO_136 | Objetivo: 0 sCMB | Destino: Tr
# [137/313] CSIRO_137 | Objetivo: 0 sCMB | Destino: Tr
# [138/313] CSIRO_138 | Objetivo: 0 sCMB | Destino: Tr
# [139/313] CSIRO_139 | Objetivo: 20 sCMB | Destino: Tr
# [140/313] CSIRO_140 | Objetivo: 20 sCMB | Destino: Tr
# [141/313] CSIRO_141 | Objetivo: 0 sCMB | Destino: Tr
# [142/313] CSIRO_142 | Objetivo: 12 sCMB | Destino: Tr
# [143/313] CSIRO_143 | Objetivo: 12 sCMB | Destino: Tr
# [144/313] CSIRO_144 | Objetivo: 20 sCMB | Destino: Tr
# [145/313] CSIRO_145 | Objetivo: 0 sCMB | Destino: Tr
# [146/313] CSIRO_146 | Objetivo: 20 sCMB | Destino: Tr
# [147/313] CSIRO_147 | Objetivo: 12 sCMB | Destino: Tr
# [148/313] CSIRO_148 | Objetivo: 12 sCMB | Destino: Tr
# [149/313] CSIRO_149 | Objetivo: 0 sCMB | Destino: Tr
# [150/313] CSIRO_150 | Objetivo: 20 sCMB | Destino: Tr
# [151/313] CSIRO_151 | Objetivo: 12 sCMB | Destino: Tr
# [152/313] CSIRO_152 | Objetivo: 20 sCMB | Destino: Tr
# [153/313] CSIRO_153 | Objetivo: 0 sCMB | Destino: Tr
# [154/313] CSIRO_154 | Objetivo: 20 sCMB | Destino: Tr
# [155/313] CSIRO_155 | Objetivo: 12 sCMB | Destino: Tr
# [156/313] CSIRO_156 | Objetivo: 20 sCMB | Destino: Tr
# [157/313] CSIRO_157 | Objetivo: 20 sCMB | Destino: Tr
# [158/313] CSIRO_158 | Objetivo: 12 sCMB | Destino: Tr
# [159/313] CSIRO_159 | Objetivo: 0 sCMB | Destino: Tr
# [160/313] CSIRO_160 | Objetivo: 12 sCMB | Destino: Tr
# [161/313] CSIRO_161 | Objetivo: 12 sCMB | Destino: Tr
# [162/313] CSIRO_162 | Objetivo: 20 sCMB | Destino: Tr
# [163/313] CSIRO_163 | Objetivo: 20 sCMB | Destino: Tr
# [164/313] CSIRO_164 | Objetivo: 20 sCMB | Destino: Tr
# [165/313] CSIRO_165 | Objetivo: 0 sCMB | Destino: Tr
# [166/313] CSIRO_166 | Objetivo: 20 sCMB | Destino: Tr
# [167/313] CSIRO_167 | Objetivo: 20 sCMB | Destino: Tr
# [168/313] CSIRO_168 | Objetivo: 0 sCMB | Destino: Tr
# [169/313] CSIRO_169 | Objetivo: 20 sCMB | Destino: Tr
# [170/313] CSIRO_170 | Objetivo: 0 sCMB | Destino: Tr
# [171/313] CSIRO_171 | Objetivo: 12 sCMB | Destino: Tr
# [172/313] CSIRO_172 | Objetivo: 0 sCMB | Destino: Tr
# [173/313] CSIRO_173 | Objetivo: 12 sCMB | Destino: Tr
# [174/313] CSIRO_174 | Objetivo: 12 sCMB | Destino: Tr
# [175/313] CSIRO_175 | Objetivo: 12 sCMB | Destino: Tr
# [176/313] CSIRO_176 | Objetivo: 20 sCMB | Destino: Tr
# [177/313] CSIRO_177 | Objetivo: 12 sCMB | Destino: Tr
# [178/313] CSIRO_178 | Objetivo: 12 sCMB | Destino: Tr
# [179/313] CSIRO_179 | Objetivo: 12 sCMB | Destino: Tr
# [180/313] CSIRO_180 | Objetivo: 12 sCMB | Destino: Tr
# [181/313] CSIRO_181 | Objetivo: 20 sCMB | Destino: Tr
# [182/313] CSIRO_182 | Objetivo: 20 sCMB | Destino: Tr
# [183/313] CSIRO_183 | Objetivo: 12 sCMB | Destino: Tr
# [184/313] CSIRO_184 | Objetivo: 20 sCMB | Destino: Tr
# [185/313] CSIRO_185 | Objetivo: 12 sCMB | Destino: Tr
# [186/313] CSIRO_186 | Objetivo: 0 sCMB | Destino: Tr
# [187/313] CSIRO_187 | Objetivo: 20 sCMB | Destino: Tr
# [188/313] CSIRO_188 | Objetivo: 12 sCMB | Destino: Tr
# [189/313] CSIRO_189 | Objetivo: 0 sCMB | Destino: Tr
# [190/313] CSIRO_190 | Objetivo: 12 sCMB | Destino: Tr
# [191/313] CSIRO_191 | Objetivo: 20 sCMB | Destino: Tr
# [192/313] CSIRO_192 | Objetivo: 12 sCMB | Destino: Tr
# [193/313] CSIRO_193 | Objetivo: 0 sCMB | Destino: Tr
# [194/313] CSIRO_194 | Objetivo: 20 sCMB | Destino: Tr
# [195/313] CSIRO_195 | Objetivo: 20 sCMB | Destino: Tr
# [196/313] CSIRO_196 | Objetivo: 12 sCMB | Destino: Tr
# [197/313] CSIRO_197 | Objetivo: 0 sCMB | Destino: Tr
# [198/313] CSIRO_198 | Objetivo: 20 sCMB | Destino: Tr
# [199/313] CSIRO_199 | Objetivo: 20 sCMB | Destino: Tr
# [200/313] CSIRO_200 | Objetivo: 0 sCMB | Destino: Tr
# [201/313] CSIRO_201 | Objetivo: 12 sCMB | Destino: Tr
# [202/313] CSIRO_202 | Objetivo: 20 sCMB | Destino: Tr
# [203/313] CSIRO_203 | Objetivo: 20 sCMB | Destino: Tr
# [204/313] CSIRO_204 | Objetivo: 20 sCMB | Destino: Tr
# [205/313] CSIRO_205 | Objetivo: 12 sCMB | Destino: Tr
# [206/313] CSIRO_206 | Objetivo: 0 sCMB | Destino: Tr
# [207/313] CSIRO_207 | Objetivo: 12 sCMB | Destino: Tr
# [208/313] CSIRO_208 | Objetivo: 12 sCMB | Destino: Tr
# [209/313] CSIRO_209 | Objetivo: 20 sCMB | Destino: Tr
# [210/313] CSIRO_210 | Objetivo: 0 sCMB | Destino: Tr
# [211/313] CSIRO_211 | Objetivo: 12 sCMB | Destino: Tr
# [212/313] CSIRO_212 | Objetivo: 0 sCMB | Destino: Tr
# [213/313] CSIRO_213 | Objetivo: 12 sCMB | Destino: Tr
# [214/313] CSIRO_214 | Objetivo: 0 sCMB | Destino: Tr
# [215/313] CSIRO_215 | Objetivo: 20 sCMB | Destino: Tr
# [216/313] CSIRO_216 | Objetivo: 12 sCMB | Destino: Tr
# [217/313] CSIRO_217 | Objetivo: 0 sCMB | Destino: Tr
# [218/313] CSIRO_218 | Objetivo: 12 sCMB | Destino: Tr
# [219/313] CSIRO_219 | Objetivo: 12 sCMB | Destino: Tr
# [220/313] CSIRO_220 | Objetivo: 20 sCMB | Destino: Tr
# [221/313] CSIRO_221 | Objetivo: 0 sCMB | Destino: Tr
# [222/313] CSIRO_222 | Objetivo: 20 sCMB | Destino: Tr
# [223/313] CSIRO_223 | Objetivo: 0 sCMB | Destino: Tr
# [224/313] CSIRO_224 | Objetivo: 12 sCMB | Destino: Tr
# [225/313] CSIRO_225 | Objetivo: 20 sCMB | Destino: Tr
# [226/313] CSIRO_226 | Objetivo: 20 sCMB | Destino: Tr
# [227/313] CSIRO_227 | Objetivo: 12 sCMB | Destino: Tr
# [228/313] CSIRO_228 | Objetivo: 12 sCMB | Destino: Tr
# [229/313] CSIRO_229 | Objetivo: 12 sCMB | Destino: Tr
# [230/313] CSIRO_230 | Objetivo: 12 sCMB | Destino: Tr
# [231/313] CSIRO_231 | Objetivo: 0 sCMB | Destino: Tr
# [232/313] CSIRO_232 | Objetivo: 12 sCMB | Destino: Tr
# [233/313] CSIRO_233 | Objetivo: 0 sCMB | Destino: Tr
# [234/313] CSIRO_234 | Objetivo: 0 sCMB | Destino: Tr
# [235/313] CSIRO_235 | Objetivo: 12 sCMB | Destino: Tr
# [236/313] CSIRO_236 | Objetivo: 12 sCMB | Destino: Tr
# [237/313] CSIRO_237 | Objetivo: 12 sCMB | Destino: Tr
# [238/313] CSIRO_238 | Objetivo: 0 sCMB | Destino: Tr
# [239/313] CSIRO_239 | Objetivo: 12 sCMB | Destino: Tr
# [240/313] CSIRO_240 | Objetivo: 12 sCMB | Destino: Tr
# [241/313] CSIRO_241 | Objetivo: 20 sCMB | Destino: Tr
# [242/313] CSIRO_242 | Objetivo: 12 sCMB | Destino: Tr
# [243/313] CSIRO_243 | Objetivo: 20 sCMB | Destino: Tr
# [244/313] CSIRO_244 | Objetivo: 20 sCMB | Destino: Tr
# [245/313] CSIRO_245 | Objetivo: 20 sCMB | Destino: Tr
# [246/313] CSIRO_246 | Objetivo: 12 sCMB | Destino: Tr
# [247/313] CSIRO_247 | Objetivo: 20 sCMB | Destino: Tr
# [248/313] CSIRO_248 | Objetivo: 0 sCMB | Destino: Tr
# [249/313] CSIRO_249 | Objetivo: 12 sCMB | Destino: Tr
# [250/313] CSIRO_250 | Objetivo: 0 sCMB | Destino: Tr
# [251/313] CSIRO_251 | Objetivo: 20 sCMB | Destino: Tr
# [252/313] CSIRO_252 | Objetivo: 12 sCMB | Destino: Tr
# [253/313] CSIRO_253 | Objetivo: 20 sCMB | Destino: Tr
# [254/313] CSIRO_254 | Objetivo: 12 sCMB | Destino: Tr
# [255/313] CSIRO_255 | Objetivo: 0 sCMB | Destino: Tr
# [256/313] CSIRO_256 | Objetivo: 20 sCMB | Destino: Tr
# [257/313] CSIRO_257 | Objetivo: 12 sCMB | Destino: Tr
# [258/313] CSIRO_258 | Objetivo: 12 sCMB | Destino: Tr
# [259/313] CSIRO_259 | Objetivo: 12 sCMB | Destino: Tr
# [260/313] CSIRO_260 | Objetivo: 0 sCMB | Destino: Tr
# [261/313] CSIRO_261 | Objetivo: 20 sCMB | Destino: Tr
# [262/313] CSIRO_262 | Objetivo: 20 sCMB | Destino: Tr
# [263/313] CSIRO_263 | Objetivo: 0 sCMB | Destino: Tr
# [264/313] CSIRO_264 | Objetivo: 12 sCMB | Destino: Tr
# [265/313] CSIRO_265 | Objetivo: 12 sCMB | Destino: Tr
# [266/313] CSIRO_266 | Objetivo: 20 sCMB | Destino: Tr
# [267/313] CSIRO_267 | Objetivo: 12 sCMB | Destino: Tr
# [268/313] CSIRO_268 | Objetivo: 12 sCMB | Destino: Tr
# [269/313] CSIRO_269 | Objetivo: 12 sCMB | Destino: Tr
# [270/313] CSIRO_270 | Objetivo: 12 sCMB | Destino: Tr
# [271/313] CSIRO_271 | Objetivo: 12 sCMB | Destino: Tr
# [272/313] CSIRO_272 | Objetivo: 20 sCMB | Destino: Tr
# [273/313] CSIRO_273 | Objetivo: 12 sCMB | Destino: Tr
# [274/313] CSIRO_274 | Objetivo: 20 sCMB | Destino: Tr
# [275/313] CSIRO_275 | Objetivo: 0 sCMB | Destino: Tr
# [276/313] CSIRO_276 | Objetivo: 12 sCMB | Destino: Tr
# [277/313] CSIRO_277 | Objetivo: 12 sCMB | Destino: Tr
# [278/313] CSIRO_278 | Objetivo: 12 sCMB | Destino: Tr
# [279/313] CSIRO_279 | Objetivo: 20 sCMB | Destino: Tr
# [280/313] CSIRO_280 | Objetivo: 12 sCMB | Destino: Tr
# [281/313] CSIRO_281 | Objetivo: 20 sCMB | Destino: Ts
# [282/313] CSIRO_282 | Objetivo: 12 sCMB | Destino: Ts
# [283/313] CSIRO_283 | Objetivo: 12 sCMB | Destino: Ts
# [284/313] CSIRO_284 | Objetivo: 20 sCMB | Destino: Ts
# [285/313] CSIRO_285 | Objetivo: 0 sCMB | Destino: Ts
# [286/313] CSIRO_286 | Objetivo: 12 sCMB | Destino: Ts
# [287/313] CSIRO_287 | Objetivo: 12 sCMB | Destino: Ts
# [288/313] CSIRO_288 | Objetivo: 12 sCMB | Destino: Ts
# [289/313] CSIRO_289 | Objetivo: 12 sCMB | Destino: Ts
# [290/313] CSIRO_290 | Objetivo: 20 sCMB | Destino: Ts
# [291/313] CSIRO_291 | Objetivo: 20 sCMB | Destino: Ts
# [292/313] CSIRO_292 | Objetivo: 0 sCMB | Destino: Ts
# [293/313] CSIRO_293 | Objetivo: 12 sCMB | Destino: Ts
# [294/313] CSIRO_294 | Objetivo: 12 sCMB | Destino: Ts
# [295/313] CSIRO_295 | Objetivo: 12 sCMB | Destino: Ts
# [296/313] CSIRO_296 | Objetivo: 0 sCMB | Destino: Ts
# [297/313] CSIRO_297 | Objetivo: 20 sCMB | Destino: Ts
# [298/313] CSIRO_298 | Objetivo: 12 sCMB | Destino: Ts
# [299/313] CSIRO_299 | Objetivo: 12 sCMB | Destino: Ts
# [300/313] CSIRO_300 | Objetivo: 0 sCMB | Destino: Ts
# [301/313] CSIRO_301 | Objetivo: 0 sCMB | Destino: Ts
# [302/313] CSIRO_302 | Objetivo: 12 sCMB | Destino: Ts
# [303/313] CSIRO_303 | Objetivo: 12 sCMB | Destino: Ts
# [304/313] CSIRO_304 | Objetivo: 20 sCMB | Destino: Ts
# [305/313] CSIRO_305 | Objetivo: 12 sCMB | Destino: Ts
# [306/313] CSIRO_306 | Objetivo: 0 sCMB | Destino: Ts
# [307/313] CSIRO_307 | Objetivo: 20 sCMB | Destino: Ts
# [308/313] CSIRO_308 | Objetivo: 12 sCMB | Destino: Ts
# [309/313] CSIRO_309 | Objetivo: 12 sCMB | Destino: Ts
# [310/313] CSIRO_310 | Objetivo: 20 sCMB | Destino: Ts
# [311/313] CSIRO_311 | Objetivo: 20 sCMB | Destino: Ts
# [312/313] CSIRO_312 | Objetivo: 0 sCMB | Destino: Ts
# [313/313] CSIRO_313 | Objetivo: 20 sCMB | Destino: Ts
#
# DATASET LISTO: 280 Entrenamiento / 33 Test

# %% [markdown]
# ## Visualización

# %%
import os
import random
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# Ruta al dataset generado
OUTPUT_DIR = "/media/PORT-DISK/Practicas/MicroBleeds_Generation/CSIRO/nnUNet_raw/Dataset112_SyntheticCMB" 
DATASET_PATH = OUTPUT_DIR  # ya definida en tu script

def get_random_lesion_bbox(label):
    coords = np.array(np.where(label > 0))
    
    if coords.shape[1] == 0:
        return None
    
    # Elegimos una lesión aleatoria
    idx = np.random.randint(coords.shape[1])
    x, y, z = coords[:, idx]
    
    return x, y, z


def crop_zoom_exact(img, lbl, center, window=25):
    cx, cy, cz = map(int, center)
    
    x_s, x_e = max(0, cx-window), min(img.shape[0], cx+window)
    y_s, y_e = max(0, cy-window), min(img.shape[1], cy+window)
    
    img_crop = img[x_s:x_e, y_s:y_e, :]
    lbl_crop = lbl[x_s:x_e, y_s:y_e, :]
    
    return img_crop, lbl_crop


def normalize(patch):
    return (patch - np.min(patch)) / (np.max(patch) - np.min(patch) + 1e-8)


def plot_triplet_exact(img_crop, lbl_crop, z_center):
    slices = [z_center-1, z_center, z_center+1]
    
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    
    for i, z in enumerate(slices):
        if z < 0 or z >= img_crop.shape[2]:
            continue
        
        img_slice = normalize(img_crop[:, :, z])
        lbl_slice = lbl_crop[:, :, z]
        
        # 🔹 SOLO IMAGEN (igual que tu pipeline)
        axes[0, i].imshow(np.rot90(img_slice), cmap='gray')
        axes[0, i].axis('off')
        
        # 🔹 IMAGEN + MÁSCARA
        axes[1, i].imshow(np.rot90(img_slice), cmap='gray')
        axes[1, i].imshow(
            np.ma.masked_where(np.rot90(lbl_slice) == 0, np.rot90(lbl_slice)),
            cmap='autumn',
            alpha=0.6
        )
        axes[1, i].axis('off')
    
    axes[0, 0].set_ylabel("Imagen", fontsize=12)
    axes[1, 0].set_ylabel("Imagen + Mask", fontsize=12)
    
    plt.tight_layout()
    plt.show()

def show_zoom_example(split="Tr"):
    images_dir = os.path.join(DATASET_PATH, f"images{split}")
    labels_dir = os.path.join(DATASET_PATH, f"labels{split}")
    
    cases = sorted([f for f in os.listdir(images_dir) if f.endswith("_0000.nii.gz")])
    
    while True:
        case = random.choice(cases)
        subject_id = case.replace("_0000.nii.gz", "")
        
        img_path = os.path.join(images_dir, case)
        lbl_path = os.path.join(labels_dir, f"{subject_id}.nii.gz")
        
        nii_img = nib.load(img_path)
        nii_lbl = nib.load(lbl_path)
        
        img = nii_img.get_fdata()
        lbl = nii_lbl.get_fdata()
        
        center = get_random_lesion_bbox(lbl)
        
        if center is None:
            continue  # saltar casos sin lesión
        
        print(f"\nCaso: {subject_id} | Lesión en {center}")

        img_crop, lbl_crop = crop_zoom_exact(img, lbl, center, window=25)
        
        # Ajustar z al nuevo sistema
        z_center = center[2]
        
        plot_triplet_exact(img_crop, lbl_crop, z_center)
        break

# ==========================
# EJECUCIÓN
# ==========================
for _ in range(15):
    show_zoom_example(split="Tr")
# Out:
# Caso: CSIRO_188 | Lesión en (np.int64(131), np.int64(158), np.int64(30))
# Caso: CSIRO_174 | Lesión en (np.int64(125), np.int64(126), np.int64(41))
# Caso: CSIRO_081 | Lesión en (np.int64(99), np.int64(90), np.int64(62))
# Caso: CSIRO_105 | Lesión en (np.int64(68), np.int64(114), np.int64(71))
# Caso: CSIRO_271 | Lesión en (np.int64(57), np.int64(157), np.int64(64))
# Caso: CSIRO_245 | Lesión en (np.int64(19), np.int64(148), np.int64(29))
# Caso: CSIRO_123 | Lesión en (np.int64(113), np.int64(100), np.int64(36))
# Caso: CSIRO_166 | Lesión en (np.int64(107), np.int64(90), np.int64(35))
# Caso: CSIRO_266 | Lesión en (np.int64(122), np.int64(93), np.int64(47))
# Caso: CSIRO_268 | Lesión en (np.int64(70), np.int64(194), np.int64(48))
# Caso: CSIRO_009 | Lesión en (np.int64(139), np.int64(127), np.int64(55))
# Caso: CSIRO_252 | Lesión en (np.int64(102), np.int64(96), np.int64(56))
# Caso: CSIRO_078 | Lesión en (np.int64(152), np.int64(117), np.int64(59))
# Caso: CSIRO_050 | Lesión en (np.int64(150), np.int64(143), np.int64(56))
# Caso: CSIRO_062 | Lesión en (np.int64(63), np.int64(67), np.int64(36))
